# %%
import geopandas as gpd
import libpysal
from spreg import GM_Lag
import pandas as pd
import numpy as np
import time
import pandas as pd
from mgwr.gwr import MGWR
from mgwr.sel_bw import Sel_BW
from sklearn.preprocessing import StandardScaler

# %%
gdb_path = r"D:\008RA\gis_process\CN_City36\CN_City36_t2.gdb"
layer_name = "全国网格_绩效t7"

target = 'performance_score'

features = [
    'buildingCount', 'totalHeight', 'avgHeight', 'basePerimeterTotal',
    'basePerimeterAvg', 'compactness', 'footprintAreaTotal', 'totalArea',
    'avgBuildingArea', 'FAR', 'coverageRatio',
    'roadDensity', 'intersectionDensity', 'poiDensity', 'poiDiversity',
    'FVC', 'permeableRatio', 'maxHeight', 'minHeight', 'heightRange', 'heightIndex',
    'heightDensity', 'heightOtherness', 'cornerCountTotal', 'basePerimeterMax',
    'basePerimeterMin', 'shapeComplexity', 'areaVariance', 'parcelArea',
    'largestPatchIndex', 'shape3DIndex', 'evennessIndex', 'cornerCountAvg',
    'buildingProximity', 'buildingMinDist', 'buildingMaxDist',
    'buildingDistAvg', 'buildingDistVar', 'SVF', 'streetRatio'
]

# %%
try:
    gdf = gpd.read_file(gdb_path, layer=layer_name)
    print(f"[{time.strftime('%H:%M:%S')}] 数据读取成功，共 {len(gdf)} 条记录。")
    
except Exception as e:
    print("读取 GDB 失败。如果报错提示驱动问题，请尝试先用 ArcGIS 将图层导出为 Shapefile 再读取。")
    print(f"错误信息: {e}")
    exit()

# 检查是否有缺失值 (NaN)，空间计量模型对 NaN 非常敏感
print(f"[{time.strftime('%H:%M:%S')}] 正在检查并清理缺失值...")
original_len = len(gdf)
# 只检查我们用到的列
cols_to_check = [target] + features
gdf = gdf.dropna(subset=cols_to_check)
if len(gdf) < original_len:
    print(f"警告：删除了 {original_len - len(gdf)} 行含有缺失值的记录。")
# Out:
# [15:03:22] 数据读取成功，共 196770 条记录。
# [15:03:22] 正在检查并清理缺失值...
# 警告：删除了 1829 行含有缺失值的记录。

# %%
gdf.shape
# Out:
# (194941, 56)

# %%
gdf.head()
# Out:
#    Global_ID   City_x  FID_1  Shape_Length  Shape_Area   City_y  NTL2023  \
# 0        0.0  Beijing    0.0        2000.0    250000.0  Beijing    6.185
# 1        1.0  Beijing    1.0        2000.0    250000.0  Beijing    5.740
# 2        2.0  Beijing    2.0        2000.0    250000.0  Beijing   11.320
# 3        3.0  Beijing    3.0        2000.0    250000.0  Beijing   11.730
# 4        4.0  Beijing    4.0        2000.0    250000.0  Beijing    8.450
#
#    NTL2023_focal    VIT202311  UHIDAY2020_07_inv  ...  buildingDistAvg  \
# 0       7.030000  1649.857143           0.472765  ...       268.089122
# 1       7.226111   155.857143           0.472765  ...       300.087841
# 2      13.616667    57.142857           0.472765  ...       283.843343
# 3      14.361667   243.571429           0.472765  ...       232.312568
# 4       9.190000     0.000000           0.472765  ...         0.000000
#
#    buildingDistVar  cluster_label  log_NTL2023_focal  log_VIT202311  \
# 0      2565.568805            5.0           0.355727       0.665412
# 1      2010.844167            5.0           0.359848       0.454023
# 2      2044.728701            5.0           0.458010       0.364892
# 3      1896.143380            5.0           0.466499       0.493915
# 4         0.000000            1.0           0.396406       0.000000
#
#    distance_to_surface  performance_score  \
# 0             0.211892           0.754223
# 1             0.353838           0.589307
# 2             0.401524           0.533904
# 3             0.305031           0.646011
# 4             0.608873           0.293002
#
#                                             geometry    centroid_x  \
# 0  MULTIPOLYGON (((12945906.677 4793764.368, 1294...  1.294616e+07
# 1  MULTIPOLYGON (((12946406.677 4793764.368, 1294...  1.294666e+07
# 2  MULTIPOLYGON (((12945906.677 4794264.368, 1294...  1.294616e+07
# 3  MULTIPOLYGON (((12946406.677 4794264.368, 1294...  1.294666e+07
# 4  MULTIPOLYGON (((12948906.677 4794264.368, 1294...  1.294916e+07
#
#      centroid_y
# 0  4.794014e+06
# 1  4.794014e+06
# 2  4.794514e+06
# 3  4.794514e+06
# 4  4.794514e+06
#
# [5 rows x 58 columns]

# %%
# CRITICAL: Replace 'City' with the actual column name in your GDB that identifies cities
# e.g., 'city_name', 'CITY_CN', or 'adcode' (if using codes like 330100 for Hangzhou)
hangzhou_gdf = gdf[gdf['City_x'] == 'Hangzhou'].copy()

# Drop NaNs to prevent errors
hangzhou_gdf = hangzhou_gdf.dropna(subset=[target] + features)

# --- 2. Prepare Data for MGWR ---
# MGWR requires inputs as numpy arrays, not DataFrames

# Coordinates (X, Y)
coords = list(zip(hangzhou_gdf.geometry.centroid.x, hangzhou_gdf.geometry.centroid.y))
coords = np.array(coords)

# Variables
X = hangzhou_gdf[features].values
y = hangzhou_gdf[target].values.reshape((-1, 1)) # Reshape is required for target

# Standardization (Highly recommended for GWR/MGWR to ensure convergence)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)
y_std = scaler.fit_transform(y)

# --- 3. Run MGWR ---
print("Selecting optimal bandwidths (this may take time)...")

# 'multi=True' enables Multi-scale (different bandwidth for each variable)
selector = Sel_BW(coords, y_std, X_std, multi=True)
bw = selector.search(verbose=True)

print("Bandwidths selected:", bw)

print("Fitting MGWR model...")
model = MGWR(coords, y_std, X_std, selector, fixed=False, kernel='bisquare')
results = model.fit()

# --- 4. Process Results ---
results.summary()

# Save local parameter estimates back to GeoDataFrame
# The order of columns in 'results.params' matches your 'features' list + intercept (if constant=True)
# Note: mgwr adds the Intercept as the last column by default if not manually handled, 
# but usually, we map the variables we care about.

# Example: Mapping the coefficient of the first feature
hangzhou_gdf['coef_' + features[0]] = results.params[:, 0]
hangzhou_gdf.plot(column='coef_' + features[0], legend=True, cmap='RdBu')
# Out:
# Selecting optimal bandwidths (this may take time)...
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\joblib\externals\loky\process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\joblib\parallel.py", line 607, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\mgwr\gwr.py", line 267, in _local_fit
#     betas, inv_xtx_xt = _compute_betas_gwr(self.y, self.X, wi)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\spglm\iwls.py", line 37, in _compute_betas_gwr
#     xtx_inv_xt = linalg.solve(xtx, xT)
#                  ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\scipy\_lib\_util.py", line 1233, in wrapper
#     return f(*arrays, *other_args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\scipy\linalg\_basic.py", line 272, in solve
#     _solve_check(n, info)
#   File "c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\scipy\linalg\_basic.py", line 43, in _solve_check
#     raise LinAlgError('Matrix is singular.')
# numpy.linalg.LinAlgError: Matrix is singular.
# """
#
# The above exception was the direct cause of the following exception:
#
# LinAlgError                               Traceback (most recent call last)
# Cell In[22], line 29
#      27 # 'multi=True' enables Multi-scale (different bandwidth for each variable)
#      28 selector = Sel_BW(coords, y_std, X_std, multi=True)
# ---> 29 bw = selector.search(verbose=True)
#      31 print("Bandwidths selected:", bw)
#      33 print("Fitting MGWR model...")
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\mgwr\sel_bw.py:318, in Sel_BW.search(self, search_method, criterion, bw_min, bw_max, interval, tol, max_iter, init_multi, tol_multi, rss_score, max_iter_multi, multi_bw_min, multi_bw_max, bws_same_times, verbose, pool)
#     315 self.int_score = not self.fixed
#     317 if self.multi:
# --> 318     self._mbw()
#     319     self.params = self.bw[3]  #params n by k
#     320     self.sel_hist = self.bw[-2] #bw searching history
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\mgwr\sel_bw.py:403, in Sel_BW._mbw(self)
#     397 def sel_func(bw_func, bw_min=None, bw_max=None):
#     398     return bw_func.search(
#     399         search_method=search_method, criterion=criterion,
#     400         bw_min=bw_min, bw_max=bw_max, interval=interval, tol=tol,
#     401         max_iter=max_iter, verbose=False)
# --> 403 self.bw = multi_bw(self.init_multi, y, X, n, k, family, self.tol_multi,
#     404                    self.max_iter_multi, self.rss_score, gwr_func,
#     405                    bw_func, sel_func, multi_bw_min, multi_bw_max,
#     406                    bws_same_times, verbose=self.verbose)
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\mgwr\search.py:199, in multi_bw(init, y, X, n, k, family, tol, max_iter, rss_score, gwr_func, bw_func, sel_func, multi_bw_min, multi_bw_max, bws_same_times, verbose)
#     195 """
#     196 Multiscale GWR bandwidth search procedure using iterative GAM backfitting
#     197 """
#     198 if init is None:
# --> 199     bw = sel_func(bw_func(y, X))
#     200     optim_model = gwr_func(y, X, bw)
#     201 else:
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\mgwr\sel_bw.py:398, in Sel_BW._mbw.<locals>.sel_func(bw_func, bw_min, bw_max)
#     397 def sel_func(bw_func, bw_min=None, bw_max=None):
# --> 398     return bw_func.search(
#     399         search_method=search_method, criterion=criterion,
#     400         bw_min=bw_min, bw_max=bw_max, interval=interval, tol=tol,
#     401         max_iter=max_iter, verbose=False)
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\mgwr\sel_bw.py:324, in Sel_BW.search(self, search_method, criterion, bw_min, bw_max, interval, tol, max_iter, init_multi, tol_multi, rss_score, max_iter_multi, multi_bw_min, multi_bw_max, bws_same_times, verbose, pool)
#     321     self.bw_init = self.bw[
#     322         -1]  #scalar, optimal bw from initial gwr model
#     323 else:
# --> 324     self._bw()
#     325     self.sel_hist = self.bw[-1]
#     327 return self.bw[0]
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\mgwr\sel_bw.py:341, in Sel_BW._bw(self)
#     338     a, c = self._init_section(self.X_glob, self.X_loc, self.coords,
#     339                               self.constant)
#     340     delta = 0.38197  #1 - (np.sqrt(5.0)-1.0)/2.0
# --> 341     self.bw = golden_section(a, c, delta, gwr_func, self.tol,
#     342                              self.max_iter, self.bw_max, self.int_score,
#     343                              self.verbose)
#     344 elif self.search_method == 'interval':
#     345     self.bw = equal_interval(self.bw_min, self.bw_max, self.interval,
#     346                              gwr_func, self.int_score, self.verbose)
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\mgwr\search.py:66, in golden_section(a, c, delta, function, tol, max_iter, bw_max, int_score, verbose)
#      64     score_b = dict[b]
#      65 else:
# ---> 66     score_b = function(b)
#      67     dict[b] = score_b
#      68     if verbose:
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\mgwr\sel_bw.py:333, in Sel_BW._bw.<locals>.<lambda>(bw)
#     329 def _bw(self):
#     330     gwr_func = lambda bw: getDiag[self.criterion](GWR(
#     331         self.coords, self.y, self.X_loc, bw, family=self.family, kernel=
#     332         self.kernel, fixed=self.fixed, constant=self.constant, offset=self.
# --> 333         offset, spherical=self.spherical, n_jobs=self.n_jobs).fit(lite=True))
#     335     self._optimized_function = gwr_func
#     337     if self.search_method == 'golden_section':
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\mgwr\gwr.py:348, in GWR.fit(self, ini_params, tol, max_iter, solve, lite, pool)
#     345 else:
#     346     m = self.points.shape[0]
# --> 348 rslt = Parallel(n_jobs=self.n_jobs)(delayed(self._local_fit)(i) for i in range(m))
#     350 rslt_list = list(zip(*rslt))
#     351 influ = np.array(rslt_list[0]).reshape(-1, 1)
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\joblib\parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\joblib\parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\joblib\parallel.py:1784, in Parallel._retrieve(self)
#    1778 while self._wait_retrieval():
#    1779     # If the callback thread of a worker has signaled that its task
#    1780     # triggered an exception, or if the retrieval loop has raised an
#    1781     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1782     # worker traceback.
#    1783     if self._aborting:
# -> 1784         self._raise_error_fast()
#    1785         break
#    1787     nb_jobs = len(self._jobs)
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\joblib\parallel.py:1859, in Parallel._raise_error_fast(self)
#    1855 # If this error job exists, immediately raise the error by
#    1856 # calling get_result. This job might not exists if abort has been
#    1857 # called directly or if the generator is gc'ed.
#    1858 if error_job is not None:
# -> 1859     error_job.get_result(self.timeout)
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\joblib\parallel.py:758, in BatchCompletionCallBack.get_result(self, timeout)
#     752 backend = self.parallel._backend
#     754 if backend.supports_retrieve_callback:
#     755     # We assume that the result has already been retrieved by the
#     756     # callback thread, and is stored internally. It's just waiting to
#     757     # be returned.
# --> 758     return self._return_or_raise()
#     760 # For other backends, the main thread needs to run the retrieval step.
#     761 try:
#
# File c:\Users\hai\anaconda3\envs\fram\Lib\site-packages\joblib\parallel.py:773, in BatchCompletionCallBack._return_or_raise(self)
#     771 try:
#     772     if self.status == TASK_ERROR:
# --> 773         raise self._result
#     774     return self._result
#     775 finally:
#
# LinAlgError: Matrix is singular.
